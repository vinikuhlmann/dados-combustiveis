# %%
import pandas as pd
from IPython.display import display

# %%
file1 = 'Arquivos\importacao-gas-natural-2000-2022.csv'
file2 = 'Arquivos\importacoes-exportacoes-derivados-2000-2022.csv'
file3 = 'Arquivos\importacoes-exportacoes-etanol-2012-2022.csv'
file4 = 'Arquivos\preços-combustiveis-2004-2021.tsv'
df1 = pd.read_csv(file1, sep=';')
df2 = pd.read_csv(file2, sep=';')
df3 = pd.read_csv(file3, sep=';')
df4 = pd.read_csv(file4, sep='\t')
display(df1.head(3))
display(df2.head(3))
display(df3.head(3))
display(df4.head(3))
# Out:
#     ANO  MÊS      PRODUTO OPERAÇÃO COMERCIAL   IMPORTADO    DISPÊNDIO
# 0  2000  ABR  GÁS NATURAL         IMPORTAÇÃO   131216,79  9577646,746
# 1  2000  AGO  GÁS NATURAL         IMPORTAÇÃO  239054,743  19376403,08
# 2  2000  DEZ  GÁS NATURAL         IMPORTAÇÃO  252528,739  21660455,62
#     ANO  MÊS  PRODUTO OPERAÇÃO COMERCIAL IMPORTADO / EXPORTADO  \
# 0  2000  ABR  ASFALTO         EXPORTAÇÃO           1362,035577
# 1  2000  AGO  ASFALTO         EXPORTAÇÃO           2700,793269
# 2  2000  DEZ  ASFALTO         EXPORTAÇÃO           1839,723077
#
#    DISPÊNDIO / RECEITA
# 0               309443
# 1               544917
# 2               426760
#     ANO  MÊS        PRODUTO OPERAÇÃO COMERCIAL IMPORTADO / EXPORTADO  \
# 0  2012  ABR  ETANOL ANIDRO         EXPORTAÇÃO             38397,357
# 1  2012  AGO  ETANOL ANIDRO         EXPORTAÇÃO            251088,364
# 2  2012  DEZ  ETANOL ANIDRO         EXPORTAÇÃO             249441,64
#
#    DISPÊNDIO / RECEITA
# 0             29005781
# 1            179069921
# 2            163571473
#   DATA INICIAL  DATA FINAL        REGIÃO            ESTADO           PRODUTO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS  ETANOL HIDRATADO
# 2   2004-05-09  2004-05-15  CENTRO OESTE       MATO GROSSO  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
# 2                  0.097                  1.18                 1.760
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
# 2                0.419                     0.070                     0.97
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                    0.9666                         0.133
# 1                      1.05                         0.115
# 2                     1.161                         0.098

# %%
df1.drop(df1[df1['OPERAÇÃO COMERCIAL'] == 'EXPORTAÇÃO'].index, inplace=True)
df2.drop(df2[df2['OPERAÇÃO COMERCIAL'] == 'EXPORTAÇÃO'].index, inplace=True)
df3.drop(df3[df3['OPERAÇÃO COMERCIAL'] == 'EXPORTAÇÃO'].index, inplace=True)
display(df1['OPERAÇÃO COMERCIAL'].unique())
display(df2['OPERAÇÃO COMERCIAL'].unique())
display(df3['OPERAÇÃO COMERCIAL'].unique())
df1.drop('OPERAÇÃO COMERCIAL', axis=1, inplace=True)
df2.drop('OPERAÇÃO COMERCIAL', axis=1, inplace=True)
df3.drop('OPERAÇÃO COMERCIAL', axis=1, inplace=True)
# Out:
# array(['IMPORTAÇÃO'], dtype=object)
# array(['IMPORTAÇÃO'], dtype=object)
# array(['IMPORTAÇÃO'], dtype=object)

# %%
df1.replace({'GÁS NATURAL': 'GNV'}, inplace=True)
df1['IMPORTADO'] *= 1000
df2.drop(df2[~df2['PRODUTO'].isin(['GASOLINA A', 'GLP', 'ÓLEO DIESEL'])].index, inplace=True)
df3.drop(df3[df3['PRODUTO'] != 'ETANOL HIDRATADO'].index, inplace=True)
df4.replace(regex={'OLEO': 'ÓLEO'}, inplace=True)
display(df1['PRODUTO'].unique())
display(df2['PRODUTO'].unique())
display(df3['PRODUTO'].unique())
display(df4['PRODUTO'].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\vinik\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\vinik\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\vinik\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'IMPORTADO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\vinik\OneDrive\Documentos\GitHub\dados-combustiveis\testing.ipynb Célula: 4 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/vinik/OneDrive/Documentos/GitHub/dados-combustiveis/testing.ipynb#ch0000002?line=0'>1</a> df1.replace({'GÁS NATURAL': 'GNV'}, inplace=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/vinik/OneDrive/Documentos/GitHub/dados-combustiveis/testing.ipynb#ch0000002?line=1'>2</a> df2.drop(df2[~df2['PRODUTO'].isin(['GASOLINA A', 'GLP', 'ÓLEO DIESEL'])].index, inplace=True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vinik/OneDrive/Documentos/GitHub/dados-combustiveis/testing.ipynb#ch0000002?line=2'>3</a> df2['IMPORTADO'] *= 1000
#       <a href='vscode-notebook-cell:/c%3A/Users/vinik/OneDrive/Documentos/GitHub/dados-combustiveis/testing.ipynb#ch0000002?line=3'>4</a> df3.drop(df3[df3['PRODUTO'] != 'ETANOL HIDRATADO'].index, inplace=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/vinik/OneDrive/Documentos/GitHub/dados-combustiveis/testing.ipynb#ch0000002?line=4'>5</a> df4.replace(regex={'OLEO': 'ÓLEO'}, inplace=True)
#
# File c:\Users\vinik\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Users\vinik\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'IMPORTADO'

# %%
df2.rename(columns={'IMPORTADO / EXPORTADO': 'IMPORTADO', 'DISPÊNDIO / RECEITA' : 'DISPÊNDIO'}, inplace=True)
df3.rename(columns={'IMPORTADO / EXPORTADO': 'IMPORTADO', 'DISPÊNDIO / RECEITA' : 'DISPÊNDIO'}, inplace=True)
display(df1.columns)
display(df2.columns)
display(df3.columns)
# Out:
# Index(['ANO', 'MÊS', 'PRODUTO', 'IMPORTADO', 'DISPÊNDIO'], dtype='object')
# Index(['ANO', 'MÊS', 'PRODUTO', 'IMPORTADO', 'DISPÊNDIO'], dtype='object')
# Index(['ANO', 'MÊS', 'PRODUTO', 'IMPORTADO', 'DISPÊNDIO'], dtype='object')

# %%
df5 = pd.concat([df1, df2, df3])
df5
# Out:
#       ANO  MÊS           PRODUTO   IMPORTADO    DISPÊNDIO
# 0    2000  ABR               GNV   131216,79  9577646,746
# 1    2000  AGO               GNV  239054,743  19376403,08
# 2    2000  DEZ               GNV  252528,739  21660455,62
# 3    2000  FEV               GNV   118705,42   9460134,94
# 4    2000  JAN               GNV  101942,422  8888167,644
# ..    ...  ...               ...         ...          ...
# 479  2021  SET  ETANOL HIDRATADO       3,721        10799
# 492  2022  ABR  ETANOL HIDRATADO       0,528         2650
# 493  2022  FEV  ETANOL HIDRATADO       0,771         4691
# 494  2022  JAN  ETANOL HIDRATADO     266,234        65581
# 495  2022  MAR  ETANOL HIDRATADO       2,732        29269
#
# [1194 rows x 5 columns]

# %%
df4
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120818   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120819   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120820   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120821   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120822   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 120818   ÓLEO DIESEL S10                            12              R$/l
# 120819   ÓLEO DIESEL S10                           100              R$/l
# 120820   ÓLEO DIESEL S10                           886              R$/l
# 120821   ÓLEO DIESEL S10                            33              R$/l
# 120822   ÓLEO DIESEL S10                            18              R$/l
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                     1.288                  0.016                 1.190
# 1                     1.162                  0.114                 0.890
# 2                     1.389                  0.097                 1.180
# 3                     1.262                  0.070                 1.090
# 4                     1.181                  0.078                 1.050
# ...                     ...                    ...                   ...
# 120818                4.582                  0.056                 4.510
# 120819                4.141                  0.187                 3.838
# 120820                4.246                  0.216                 3.769
# 120821                4.464                  0.205                 4.190
# 120822                4.352                  0.156                 4.199
#
#         PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                0.463                     0.012
# 1                      1.449                0.399                     0.098
# 2                      1.760                0.419                     0.070
# 3                      1.509                0.432                     0.055
# 4                      1.400                 0.24                     0.066
# ...                      ...                  ...                       ...
# 120818                 4.690             -99999.0                     0.012
# 120819                 4.739             -99999.0                     0.045
# 120820                 5.199             -99999.0                     0.051
# 120821                 4.699             -99999.0                     0.046
# 120822                 4.699             -99999.0                     0.036
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.11
# 1                         0.763                      0.088
# 2                          0.97                      0.095
# 3                          0.83                      0.119
# 4                         0.941                      0.077
# ...                         ...                        ...
# 120818                 -99999.0                   -99999.0
# 120819                 -99999.0                   -99999.0
# 120820                 -99999.0                   -99999.0
# 120821                 -99999.0                   -99999.0
# 120822                 -99999.0                   -99999.0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 120818                  -99999.0                  -99999.0
# 120819                  -99999.0                  -99999.0
# 120820                  -99999.0                  -99999.0
# 120821                  -99999.0                  -99999.0
# 120822                  -99999.0                  -99999.0
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                              0.133
# 1                              0.115
# 2                              0.098
# 3                              0.143
# 4                              0.082
# ...                              ...
# 120818                      -99999.0
# 120819                      -99999.0
# 120820                      -99999.0
# 120821                      -99999.0
# 120822                      -99999.0
#
# [120823 rows x 18 columns]

# %%
df4['UNIDADE DE MEDIDA'].unique()
# Out:
# array(['R$/l', 'R$/13Kg', 'R$/m3'], dtype=object)

# %%
df4[df4['UNIDADE DE MEDIDA'] == 'R$/13Kg']['PRODUTO'].unique()
# Out:
# array(['GLP'], dtype=object)
